# %%
my_var = "hello"
print(my_var)
# Out:
# hello

# %%
1var = "hello"
# Out:
#   Cell In[1], line 1
#     1var = "hello"
#     ^
# SyntaxError: invalid decimal literal

# %%
var1 = "hello"

# %%
user_name = "dan"
item_code = 101

# %%
item = 101
type(item)
# Out:
# int

# %%
item = "code 101"
type(item)
# Out:
# str

# %%
item = 101

# %%
item = "code 101"
